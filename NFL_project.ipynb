# %%
# Import needed dependencies 
import matplotlib.pyplot as plt 
import pandas as pd 
import scipy.stats as st 
import numpy as np 
from pprint import pprint 

#Set CSV Locations for each NFL Data Set in variable
combine_2000 = "Resources/combine_data.csv"
nfl_stats = "Resources/nfl_stats/Basic_Stats.csv"

# Use pandas csv reader to review data
combine_2000 = pd.read_csv(combine_2000)
nfl_stats = pd.read_csv(nfl_stats)

# %%
combine_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6218 entries, 0 to 6217
# Data columns (total 16 columns):
# Player       6218 non-null object
# Pos          6218 non-null object
# Ht           6218 non-null int64
# Wt           6218 non-null int64
# Forty        6046 non-null float64
# Vertical     4796 non-null float64
# BenchReps    4212 non-null float64
# BroadJump    4754 non-null float64
# Cone         3993 non-null float64
# Shuttle      4063 non-null float64
# Year         6218 non-null int64
# Pfr_ID       4895 non-null object
# AV           6218 non-null float64
# Team         3738 non-null object
# Round        3738 non-null float64
# Pick         3738 non-null float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 777.3+ KB

# %%
#view first 10 lines of combine_2000 data. Analyze data set to set goals for clean up
combine_2000.head(20)
# Out:
#               Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0       John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1    Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2     Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3       Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4   Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
# 5        Jake Arians    K  70  202    NaN       NaN        NaN        NaN
# 6    LaVar Arrington  OLB  75  250   4.53       NaN        NaN        NaN
# 7       Corey Atkins  OLB  72  237   4.72      31.0       21.0      112.0
# 8     Kyle Atteberry    K  72  167    NaN       NaN        NaN        NaN
# 9      Reggie Austin   CB  69  175   4.44      35.0       17.0      119.0
# 10        John Baker    P  75  227    NaN       NaN        NaN        NaN
# 11    Mark Baniewicz   OT  78  312   5.34      28.0       20.0       96.0
# ...

# %%
#view first 10 lines of nfl_stats data. Analyze data set to set goals for clean up
nfl_stats.head(20)
# Out:
#      Age        Birth Place    Birthday              College Current Status  \
# 0    NaN  Grand Rapids , MI   5/23/1921           Notre Dame        Retired
# 1    NaN        Dayton , OH  12/21/1930               Dayton        Retired
# 2   56.0        Temple , TX   9/11/1960       Louisiana Tech        Retired
# 3   30.0   New Orleans , LA   9/30/1986                  LSU        Retired
# 4   25.0       Detroit , MI   3/31/1992     Central Michigan         Active
# 5    NaN        Sumner , IL   9/11/1892             Illinois        Retired
# 6    NaN        Casper , WY   9/16/1920            Wisconsin        Retired
# 7   22.0       Navarre , FL   1/31/1995              Clemson         Active
# 8    NaN                NaN         NaN           No College        Retired
# 9   98.0      Alverton , PA   2/23/1919             Duquesne        Retired
# 10   NaN       Orlando , FL    3/8/1945       Tennessee Tech        Retired
# ...

# %%
sorted_wr_col = combine_2000[["Pos","Ht","Wt","Forty","Vertical"]]
print(sorted_wr_col.head(17))
# Out:
#     Pos  Ht   Wt  Forty  Vertical
# 0   OLB  76  252   4.55       NaN
# 1    RB  72  218   4.58       NaN
# 2    OT  76  334   5.56      25.0
# 3    TE  74  253   4.97      29.0
# 4    CB  74  206   4.55      34.0
# 5     K  70  202    NaN       NaN
# 6   OLB  75  250   4.53       NaN
# 7   OLB  72  237   4.72      31.0
# 8     K  72  167    NaN       NaN
# 9    CB  69  175   4.44      35.0
# 10    P  75  227    NaN       NaN
# 11   OT  78  312   5.34      28.0
# 12   FS  72  208   4.62      35.0
# 13   CB  70  199   4.44      37.5
# 14   CB  73  192   4.43      38.5
# 15    P  74  200    NaN       NaN
# 16   OG  75  312   5.19       NaN

# %%
WR = combine_2000[sorted_wr_col["Pos"] == "WR"]
print(WR)
# Out:
#                         Player Pos  Ht   Wt  Forty  Vertical  BenchReps  \
# 39             Plaxico Burress  WR  77  231   4.59      33.0        NaN
# 46                 Kwame Cavil  WR  74  208   4.54      39.5        NaN
# 58                  Chris Cole  WR  72  191   4.37      37.5        NaN
# 60               Chris Coleman  WR  72  211   4.61      32.5        NaN
# 61            Laveranues Coles  WR  71  192   4.41      34.0        NaN
# 70               Chris Daniels  WR  75  217   4.74      33.0        NaN
# 71             Brandon Daniels  WR  70  211   4.54       NaN        NaN
# 75               JaJuan Dawson  WR  73  199   4.55      34.0        NaN
# 81                  Ron Dugans  WR  73  206   4.58       NaN        NaN
# 88                 Matt Farmer  WR  72  190   4.51      33.0        NaN
# 89                Danny Farmer  WR  75  217   4.58       NaN        NaN
# 91               Chafie Fields  WR  73  196   4.43       NaN        NaN
# ...
