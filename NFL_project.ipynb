# %% [markdown]
# # Scouting for All Pro/Pro-bowl Wide Recievers
# **This project objective to use NFL combine statiscs data to explore any common stats that makes up a Pro-bowll/All-Pro WR.
# ** We will use statisical analysis to see if there is any commonality within the Combine stats, to predict the future succuess of an NFL Wide Recievers

# %%
# Import needed dependencies 
import matplotlib.pyplot as plt 
import pandas as pd 
import scipy.stats as st 
import numpy as np 
from pprint import pprint 

#Set CSV Locations for each NFL Data Set in variable
combine_2000 = "Resources/combine_data.csv"
nfl_stats = "Resources/nfl_stats/Basic_Stats.csv"

# Use pandas csv reader to review data
combine_2000 = pd.read_csv(combine_2000)
nfl_stats = pd.read_csv(nfl_stats)

# %%
combine_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6218 entries, 0 to 6217
# Data columns (total 16 columns):
# Player       6218 non-null object
# Pos          6218 non-null object
# Ht           6218 non-null int64
# Wt           6218 non-null int64
# Forty        6046 non-null float64
# Vertical     4796 non-null float64
# BenchReps    4212 non-null float64
# BroadJump    4754 non-null float64
# Cone         3993 non-null float64
# Shuttle      4063 non-null float64
# Year         6218 non-null int64
# Pfr_ID       4895 non-null object
# AV           6218 non-null float64
# Team         3738 non-null object
# Round        3738 non-null float64
# Pick         3738 non-null float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 777.3+ KB

# %%
#view first 10 lines of combine_2000 data. Analyze data set to set goals for clean up
combine_2000.head(20)
# Out:
#               Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0       John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1    Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2     Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3       Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4   Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
# 5        Jake Arians    K  70  202    NaN       NaN        NaN        NaN
# 6    LaVar Arrington  OLB  75  250   4.53       NaN        NaN        NaN
# 7       Corey Atkins  OLB  72  237   4.72      31.0       21.0      112.0
# 8     Kyle Atteberry    K  72  167    NaN       NaN        NaN        NaN
# 9      Reggie Austin   CB  69  175   4.44      35.0       17.0      119.0
# 10        John Baker    P  75  227    NaN       NaN        NaN        NaN
# 11    Mark Baniewicz   OT  78  312   5.34      28.0       20.0       96.0
# ...

# %%
#view first 10 lines of nfl_stats data. Analyze data set to set goals for clean up
nfl_stats.head(20)
# Out:
#      Age        Birth Place    Birthday              College Current Status  \
# 0    NaN  Grand Rapids , MI   5/23/1921           Notre Dame        Retired
# 1    NaN        Dayton , OH  12/21/1930               Dayton        Retired
# 2   56.0        Temple , TX   9/11/1960       Louisiana Tech        Retired
# 3   30.0   New Orleans , LA   9/30/1986                  LSU        Retired
# 4   25.0       Detroit , MI   3/31/1992     Central Michigan         Active
# 5    NaN        Sumner , IL   9/11/1892             Illinois        Retired
# 6    NaN        Casper , WY   9/16/1920            Wisconsin        Retired
# 7   22.0       Navarre , FL   1/31/1995              Clemson         Active
# 8    NaN                NaN         NaN           No College        Retired
# 9   98.0      Alverton , PA   2/23/1919             Duquesne        Retired
# 10   NaN       Orlando , FL    3/8/1945       Tennessee Tech        Retired
# ...

# %% [markdown]
# * Sorting the Combine stats to focus on particular columns to what makes a pro-bowl Wide Reciever:
#     In the sorted column we'll focus on :
#     1. height of player
#     2. Weight of player
#     3. Run Forty time
#     4. Vertical Jump
#     5. Year they were drafted

# %%
sorted_wr_col = combine_2000[["Player","Pos","Ht","Wt","Forty","Vertical","Year"]]
print(sorted_wr_col.head(17))
# Out:
#               Player  Pos  Ht   Wt  Forty  Vertical  Year
# 0       John Abraham  OLB  76  252   4.55       NaN  2000
# 1    Shaun Alexander   RB  72  218   4.58       NaN  2000
# 2     Darnell Alford   OT  76  334   5.56      25.0  2000
# 3       Kyle Allamon   TE  74  253   4.97      29.0  2000
# 4   Rashard Anderson   CB  74  206   4.55      34.0  2000
# 5        Jake Arians    K  70  202    NaN       NaN  2000
# 6    LaVar Arrington  OLB  75  250   4.53       NaN  2000
# 7       Corey Atkins  OLB  72  237   4.72      31.0  2000
# 8     Kyle Atteberry    K  72  167    NaN       NaN  2000
# 9      Reggie Austin   CB  69  175   4.44      35.0  2000
# 10        John Baker    P  75  227    NaN       NaN  2000
# 11    Mark Baniewicz   OT  78  312   5.34      28.0  2000
# 12    Rashidi Barnes   FS  72  208   4.62      35.0  2000
# 13     David Barrett   CB  70  199   4.44      37.5  2000
# 14    William Bartee   CB  73  192   4.43      38.5  2000
# ...

# %% [markdown]
# Pulling all WR comps that is needed

# %%
WR = sorted_wr_col["Pos"] == "WR"
print(sorted_wr_col[WR])
# Out:
#                         Player Pos  Ht   Wt  Forty  Vertical  Year
# 39             Plaxico Burress  WR  77  231   4.59      33.0  2000
# 46                 Kwame Cavil  WR  74  208   4.54      39.5  2000
# 58                  Chris Cole  WR  72  191   4.37      37.5  2000
# 60               Chris Coleman  WR  72  211   4.61      32.5  2000
# 61            Laveranues Coles  WR  71  192   4.41      34.0  2000
# 70               Chris Daniels  WR  75  217   4.74      33.0  2000
# 71             Brandon Daniels  WR  70  211   4.54       NaN  2000
# 75               JaJuan Dawson  WR  73  199   4.55      34.0  2000
# 81                  Ron Dugans  WR  73  206   4.58       NaN  2000
# 88                 Matt Farmer  WR  72  190   4.51      33.0  2000
# 89                Danny Farmer  WR  75  217   4.58       NaN  2000
# 91               Chafie Fields  WR  73  196   4.43       NaN  2000
# 95                Larry Foster  WR  70  198   4.55      37.0  2000
# ...

# %%
sorted_forty_wr = sorted_wr_col.sort_values("Forty", ascending=True)
print(sorted_forty_wr[WR])
# Out:
#                     Player Pos  Ht   Wt  Forty  Vertical  Year
# 5805             John Ross  WR  71  188   4.22      37.0  2017
# 914      Donte' Stallworth  WR  72  197   4.22       NaN  2002
# 4575            Dri Archer  WR  68  173   4.26      38.0  2014
# 4332      Marquise Goodwin  WR  69  183   4.27       NaN  2013
# 5122           J.J. Nelson  WR  70  156   4.28      36.0  2015
# 3353           Jacoby Ford  WR  69  186   4.28      33.5  2010
# 1811         Jerome Mathis  WR  71  181   4.28      35.5  2005
# 3056   Darrius Heyward-Bey  WR  74  210   4.30      38.5  2009
# 3222           Mike Thomas  WR  68  195   4.30      40.5  2009
# 2367          Yamon Figurs  WR  71  174   4.30       NaN  2007
# 2970           Deon Butler  WR  70  182   4.31      34.5  2009
# 3227      Tiquan Underwood  WR  73  184   4.31      41.5  2009
# 529           Santana Moss  WR  70  184   4.31       NaN  2001
# 5811         Curtis Samuel  WR  71  196   4.31      37.0  2017
# ...
